# %% [markdown]
# ### function to calculate minimum probility p_min to check given condition

# %%
def p_minimum(n,trail_cap,B_cap,B_bar):
        p_min = 1.0;
        for i in range(0,n-1):
            p_min *= trail_cap[i].wt
        p_min = p_min * B_cap[nrounds - 1 - (n + 1)]; 
        p_min = B_bar/p_min 
        return p_min

# %% [markdown]
# ### function to check given inputs are available in highways path list or not

# %%
def highwaylist():
    alph,bet,gam,pro = [],[],[],[]
    with open('alph.txt') as ip1, open('bet.txt') as ip2, open('gam.txt') as ip3, open('pro.txt') as ip4:
        for i1,i2,i3,i4 in zip(ip1,ip2,ip3,ip4):
            hw.append(NMTS(int(i1.strip()),int(i2.strip()),int(i3.strip()),float(i4.strip())))

# %% [markdown]
# ### function to calculate weight

# %%
def weight(alpha1,beta1,gamma1): 
    if(alpha1==0 and beta1==0 and gamma1==0):
        return -200
    x1= (alpha1 << 1)& mask
    y1= (beta1  << 1)& mask
    z1= (gamma1  << 1)& mask
    not_x=(x1^mask)
    eq=((not_x)^y1)&(not_x^z1)
    s=eq&(alpha1^beta1^gamma1^(y1))
    if(s==0):        
        h=bin((~eq)& mask)
        wt=(h[1:].count("1"))
        return math.pow(2,-wt)
    else:
        return -200

# %%
#weight(0, 673, 0)

# %%
def PDDT(n,p_thres,k,wt,da,db,dc,s,maxddt,ddt):
    if(n==k):
        ddt.append(NMTS(da,db,dc,wt))
        #print(da,db,dc,s)
        if(wt>=s):
            s=wt
            maxddt[0]=NMTS(da,db,dc,s)
            #print(maxddt[0].dx,maxddt[0].dy,maxddt[0].dz,maxddt[0].wt,s)
        #print(da,db,dc,wt)
        return 
    
    for z in range(0,2):
        new_dc= (dc | (z<<k) & mask)
        wt= weight(da,db,new_dc)
        if(wt >= p_thres or (k+1)!=n):                    
            PDDT(n,p_thres,k+1,wt,da,db,new_dc,s,maxddt,ddt) 
            
    if(len(ddt)==0):
        return 0,ddt,maxddt
    else:
        return 1,ddt,maxddt

# %%
#ck,ddt,maxddt=PDDT(16,0.1,0,1,256,33802,0,s)
#print(ck)

# %% [markdown]
# ### function to perform left and right circular rotation

# %%
#right circular shifts
def ROR(x,r):
    x = ((x << (SPECK_TYPE - r)) + (x >> r)) & mask
    return x

#left circular shifts
def ROL(x,r):
    x = ((x >> (SPECK_TYPE - r)) + (x << r)) & mask
    return x

# %% [markdown]
# ### main function for threshold search

# %%
def threshold_search(n,nrounds,hw,B_cap,B_bar,st0,st1,op,w1):
    if(n == 0): 
        #print(n)
        #print("loop")
        #print(st1,st0,op,w1)
        B_cap_temp[nrounds-1]=w1*B_cap[nrounds-1-(n+1)]
        if(B_cap_temp[nrounds-1]>B_bar):
            trail_cap[n]= NMTS(ROL(st1,alpha),st0,op,w1)
            st1=op
            st0=ROL(st0,beta)^st1
            return threshold_search(n+1,nrounds,hw,B_cap,B_bar,st0,st1,op,w1)
        else:
            return B_bar,B_cap 
            
    if((n > 0) & (n != (nrounds - 1))):
        #print(n)
        st1=ROR(st1,alpha)
        p_min=p_minimum(n,trail_cap,B_cap,B_bar)
        croad=[]
        #function that check output is in highway and weight is greater than p_min or not, if it is update croad
        maxddt,ddt,max_p=[0]*1,[],0
        ck,ddt,maxddt=PDDT(SPECK_TYPE,0.1,0,1,st1,st0,0,max_p,maxddt,ddt)
        if(ck==1):
            croad.append(ddt[0])
        #opcheck_in_highways(0,p_min,st1,st0)
        #if croad is still empty then fill it with max probility value for other outputs except highway
        if(len(croad) == 0):
            maxddt,ddt,max_p=[0]*1,[],0
            #print(st1,st0,max_p)
            ck,ddt,maxddt=PDDT(SPECK_TYPE,0,0,1,st1,st0,0,max_p,maxddt,ddt)
            #max_p,output,ck=max(0,st1,st0)
            if(ck==1):
                #print(st1,st0,output,max_p)
                #croad.append(NMTS(st1,st0,output,max_p))
                croad.append(maxddt[0])
            else:
                return B_bar,B_cap
        
        #for i in range(0,len(croad)):
            #print(croad[i].dx,croad[i].dy,croad[i].dz,croad[i].wt)
        #check the inputs in highway or not 
        crhw = []
        temphw=[0]*1
        maxddt,ddt,max_p=[0]*1,[],0
        ck,ddt,maxddt=PDDT(SPECK_TYPE,0.1,0,1,st1,st0,0,max_p,maxddt,ddt)
        #val1,val2,val3,w,chk= searchinhighway(st1,st0)
        if(ck==1):
            temphw[0]=NMTS(maxddt[0].dx,maxddt[0].dy,maxddt[0].dz,maxddt[0].wt)
            crhw.extend(temphw)
        
        crhw.extend(croad)
        p_r=1
        for i in range(0,n):
            p_r *= trail_cap[i].wt
        for i in range(0,len(crhw)):
            B_cap_temp[nrounds-1]= p_r * crhw[i].wt * B_cap[nrounds - 1 - (n + 1)]
            if(B_cap_temp[nrounds-1]>B_bar):
                trail_cap[n]=NMTS(ROL(crhw[i].dx,alpha),crhw[i].dy,crhw[i].dz,crhw[i].wt)
                st1=crhw[i].dz
                st0=ROL(st0,beta)^st1
                return threshold_search(n+1,nrounds,hw,B_cap,B_bar,st0,st1,op,w1)
            else:
                return B_bar,B_cap
            return B_bar,B_cap
                    
    if(n ==(nrounds - 1)):
        st1=ROR(st1,alpha)
        #print(n)
        maxddt,ddt,max_p=[0]*1,[],0
        ck,ddt,maxddt=PDDT(SPECK_TYPE,0.1,0,1,st1,st0,0,max_p,maxddt,ddt)
        #max_p,output,ck=max(0.1,st1,st0)
        if(ck!=0):
            p=maxddt[0].wt
            op=maxddt[0].dz
        else:
            maxddt,ddt,max_p=[0]*1,[],0
            ck,ddt,maxddt=PDDT(SPECK_TYPE,0,0,1,st1,st0,0,max_p,maxddt,ddt)
            #print(st1,st0,max_p)
            #max_p,output,ck=max(0,st1,st0)
            if(ck==1):
                p=maxddt[0].wt
                op=maxddt[0].dz
            if(p>=0.1):
                hw.append(NMTS(st1,st0,op,p))
        if(ck==0):
            return B_bar,B_cap             
        p_r=1
        for i in range(0,n):
            p_r *= trail_cap[i].wt
        B_cap_temp[nrounds-1]=p * p_r
        if(B_cap_temp[nrounds-1]>B_bar):
            print(n)
            #print ("%.16f %.16f" % (B_cap_temp[n],B_bar))
            trail_cap[n]=NMTS(ROL(st1,alpha),st0,op,p)
            B_bar=B_cap_temp[nrounds-1]
            for i in range(0,len(B_cap)):
                B_cap[i]=trail_cap[i].wt
                B_bar=B_cap_temp[n]  
            for i in range(0,len(trail_cap)):
                print(ROR(trail_cap[i].dx,alpha),trail_cap[i].dy,trail_cap[i].dz,trail_cap[i].wt)
            return B_bar,B_cap
        else:
            return B_bar,B_cap

# %%
import random
import math 
#alpha beta are for left and right circular shift     
alpha, beta = 7,2
#speck total number of round epresented by nrounds
nrounds,n,s=9,0,0
SPECK_TYPE=16
mask,wshift = 2 ** 16 - 1, 15
#B_cap=[0.00048,0.00048,0.0625,0.00048,0.00048,0.00048,0.00048,0.00048,0.00048]
B_cap,B_bar=[2**(-11),2**(-22),2**(-33),2**(-38),2**(-49),2**(-60),2**(-71),2**(-82),2**(-91)],2 ** (-91)
#B_cap,B_bar=[2**(-11),2**(-22),2**(-33),2**(-38)],2 ** (-38)
trail_cap,trail_bar=[0]*nrounds, [0]*nrounds
croad,hw,B_cap_temp=[],[],[0]*nrounds
st0=0
st1=0
hlen=408603
max_p,output=0,0
maxddt,ddt,max_p=[0]*1,[],0
print ("%.30f" % B_bar)
class NMTS(object):
    """__init__() functions as the class constructor"""
    def __init__(self, dx=None, dy=None, dz=None, wt=None):
        self.dx = dx
        self.dy = dy
        self.dz = dz
        self.wt = wt
        
highwaylist()
for ch in range(1,len(hw)):
    #print(n,nrounds,B_bar,hw[ch].dx,hw[ch].dy,hw[ch].dz,hw[ch].wt)
    B_bar,B_cap =threshold_search(n,nrounds,hw,B_cap,B_bar,hw[ch].dx,hw[ch].dy,hw[ch].dz,hw[ch].wt)
    #print("%.30f" %B_bar,ch)
    print(B_bar,ch)
    #for i in range(0,len(B_cap)):
        #print(B_cap[i])
# Out:
# 0.000000000000000000000000000404
# 8
# 0 32768 32768 1.0
# 256 32770 33030 0.125
# 3330 33036 65534 0.0001220703125
# 65023 64460 65007 0.015625
# 57339 4828 64223 0.001953125
# 49141 45487 64950 0.001953125
# 28155 15112 44527 0.00048828125
# 57179 16847 32106 0.0009765625
# 54522 31319 24411 0.0009765625
# 4.235164736271502e-22 1
# 8
# 32768 32768 0 1.0
# 0 2 14 0.125
# 7168 6 65534 6.103515625e-05
# 65023 65510 65015 0.0625
# 61435 620 64367 0.00048828125
# 57334 62175 56023 0.0078125
# 44981 4520 65023 0.000244140625
# 65531 47967 47962 0.015625
# 46454 22052 57278 0.0009765625
# 6.776263578034403e-21 2
# 6.776263578034403e-21 3
# 6.776263578034403e-21 4
# 6.776263578034403e-21 5
# 6.776263578034403e-21 6
# 6.776263578034403e-21 7
# 6.776263578034403e-21 8
# 6.776263578034403e-21 9
# 6.776263578034403e-21 10
# 6.776263578034403e-21 11
# 6.776263578034403e-21 12
# 6.776263578034403e-21 13
# 6.776263578034403e-21 14
# 6.776263578034403e-21 15
# 6.776263578034403e-21 16
# 6.776263578034403e-21 17
# 6.776263578034403e-21 18
# 8
# 16384 16384 0 0.5
# 0 1 7 0.125
# 3584 3 65535 3.0517578125e-05
# 65535 65523 65530 0.125
# 62975 53 65462 0.000244140625
# 28159 65378 28027 0.0078125
# 63194 37104 57310 0.0009765625
# 48575 39964 57311 0.001953125
# 49087 44973 61422 0.015625
# 1.3552527156068805e-20 19
# 1.3552527156068805e-20 20
# 1.3552527156068805e-20 21
# 1.3552527156068805e-20 22
# 1.3552527156068805e-20 23
# 1.3552527156068805e-20 24
# 1.3552527156068805e-20 25
# 1.3552527156068805e-20 26
# 8
# 8192 0 8192 0.5
# 64 8192 8384 0.125
# 32833 41152 65407 6.103515625e-05
# 65534 31869 32639 0.03125
# 65278 36490 61420 0.001953125
# 55775 54726 65527 0.00390625
# 61439 43244 48879 0.00390625
# 57213 7517 64990 0.0078125
# 48635 34986 61103 0.0009765625
# 2.710505431213761e-20 27
# 2.710505431213761e-20 28
# 2.710505431213761e-20 29
# 2.710505431213761e-20 30
# 2.710505431213761e-20 31
# 2.710505431213761e-20 32
# 2.710505431213761e-20 33
# 2.710505431213761e-20 34
# 2.710505431213761e-20 35
# 2.710505431213761e-20 36
# 2.710505431213761e-20 37
# 2.710505431213761e-20 38
# 2.710505431213761e-20 39
# 2.710505431213761e-20 40
# 2.710505431213761e-20 41
# 2.710505431213761e-20 42
# 2.710505431213761e-20 43
# 2.710505431213761e-20 44
# 2.710505431213761e-20 45
# 2.710505431213761e-20 46
# 2.710505431213761e-20 47
# 2.710505431213761e-20 48
# 2.710505431213761e-20 49
# 2.710505431213761e-20 50
# 2.710505431213761e-20 51
# 2.710505431213761e-20 52
# 2.710505431213761e-20 53
# 2.710505431213761e-20 54
# 2.710505431213761e-20 55
# 2.710505431213761e-20 56
# 2.710505431213761e-20 57
# 2.710505431213761e-20 58
# 2.710505431213761e-20 59
# 2.710505431213761e-20 60
# 2.710505431213761e-20 61
# 2.710505431213761e-20 62
# 2.710505431213761e-20 63
# 2.710505431213761e-20 64
# 2.710505431213761e-20 65
# 2.710505431213761e-20 66
# 2.710505431213761e-20 67
# 2.710505431213761e-20 68
# 2.710505431213761e-20 69
# 2.710505431213761e-20 70
# 2.710505431213761e-20 71
# 2.710505431213761e-20 72
# 2.710505431213761e-20 73
# 2.710505431213761e-20 74
# 2.710505431213761e-20 75
# 2.710505431213761e-20 76
# 2.710505431213761e-20 77
# 2.710505431213761e-20 78
# 2.710505431213761e-20 79
# 2.710505431213761e-20 80
# 2.710505431213761e-20 81
# 2.710505431213761e-20 82
# 2.710505431213761e-20 83
# 2.710505431213761e-20 84
# 2.710505431213761e-20 85
# 2.710505431213761e-20 86
# 2.710505431213761e-20 87
# 2.710505431213761e-20 88
# 2.710505431213761e-20 89
# 2.710505431213761e-20 90
# 2.710505431213761e-20 91
# 2.710505431213761e-20 92
# 2.710505431213761e-20 93
# 2.710505431213761e-20 94
# 2.710505431213761e-20 95
# 2.710505431213761e-20 96
# 2.710505431213761e-20 97
# 2.710505431213761e-20 98
# 2.710505431213761e-20 99
# 2.710505431213761e-20 100
# 2.710505431213761e-20 101
# 2.710505431213761e-20 102
# 2.710505431213761e-20 103
