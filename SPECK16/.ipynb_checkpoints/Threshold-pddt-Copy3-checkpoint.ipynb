# %% [markdown]
# ### function to calculate minimum probility p_min to check given condition

# %%
def p_minimum(n,trail_cap,B_cap,B_bar):
        p_min = 1.0;
        for i in range(0,n):
            p_min *= trail_cap[i].wt
        p_min = p_min * B_cap[nrounds - 1 - (n + 1)]; 
        p_min = B_bar/p_min
        #print(B_bar,p_min)
        return p_min

# %% [markdown]
# ### function to check given inputs are available in highways path list or not

# %%
def highwaylist():
    alph,bet,gam,pro = [],[],[],[]
    with open('alph.txt') as ip1, open('bet.txt') as ip2, open('gam.txt') as ip3, open('pro.txt') as ip4:
        for i1,i2,i3,i4 in zip(ip1,ip2,ip3,ip4):
            hw.append(NMTS(int(i1.strip()),int(i2.strip()),int(i3.strip()),float(i4.strip())))

# %% [markdown]
# ### function to calculate weight

# %%
def weight(alpha1,beta1,gamma1): 
    if(alpha1==0 and beta1==0 and gamma1==0):
        return -200
    x1= (alpha1 << 1)& mask
    y1= (beta1  << 1)& mask
    z1= (gamma1  << 1)& mask
    not_x=(x1^mask)
    eq=((not_x)^y1)&(not_x^z1)
    s=eq&(alpha1^beta1^gamma1^(y1))
    if(s==0):        
        h=bin((~eq)& mask)
        wt=(h[1:].count("1"))
        return math.pow(2,-wt)
    else:
        return -200

# %%
#weight(0, 673, 0)

# %%
def PDDT(n,p_thres,k,wt,da,db,dc,s,maxddt,ddt):
    if(n==k):
        ddt.append(NMTS(da,db,dc,wt))
        #print(da,db,dc,s)
        if(wt>=s):
            s=wt
            maxddt[0]=NMTS(da,db,dc,s)
            #print(maxddt[0].dx,maxddt[0].dy,maxddt[0].dz,maxddt[0].wt,s)
        #print(da,db,dc,wt)
        return 
    
    for z in range(0,2):
        new_dc= (dc | (z<<k) & mask)
        wt= weight(da,db,new_dc)
        if(wt >= p_thres or (k+1)!=n):                    
            PDDT(n,p_thres,k+1,wt,da,db,new_dc,s,maxddt,ddt) 
            
    if(len(ddt)==0):
        return 0,ddt,maxddt
    else:
        return 1,ddt,maxddt

# %%
#ck,ddt,maxddt=PDDT(16,0.1,0,1,256,33802,0,s)
#print(ck)

# %% [markdown]
# ### function to perform left and right circular rotation

# %%
#right circular shifts
def ROR(x,r):
    x = ((x << (SPECK_TYPE - r)) + (x >> r)) & mask
    return x

#left circular shifts
def ROL(x,r):
    x = ((x >> (SPECK_TYPE - r)) + (x << r)) & mask
    return x

# %% [markdown]
# ### main function for threshold search

# %%
def threshold_search(n,nrounds,hw,B_cap,B_bar,B_barlist,st0,st1,op,w1):
    if(n == 0): 
        maxddt,ddt,max_p=[0]*1,[],0
        ck,ddt,maxddt=PDDT(SPECK_TYPE,0,0,1,st1,st0,0,max_p,maxddt,ddt)
        if(ck==1):
            w1=maxddt[0].wt
            op=maxddt[0].dz
        else:
            return
        #print(n)
        #print("loop")
        #print(st1,st0,op,w1)
        B_cap_temp[nrounds-1]=w1*B_cap[nrounds-1-(n+1)]
        if(B_cap_temp[nrounds-1]>B_bar):
            B_barlist[n]=w1
            trail_cap[n]= NMTS(ROL(st1,alpha),st0,op,w1)
            st1=op
            st0=ROL(st0,beta)^st1
            return threshold_search(n+1,nrounds,hw,B_cap,B_bar,B_barlist,st0,st1,op,w1)
        else:
            return B_bar,B_cap 
            
    if((n > 0) & (n != (nrounds - 1))):
        #print(n)
        st1=ROR(st1,alpha)
        p_min=p_minimum(n,trail_cap,B_cap,B_bar)
        croad=[]
        #function that check output is in highway and weight is greater than p_min or not, if it is update croad
        maxddt,ddt,max_p=[0]*1,[],0
        ck,ddt,maxddt=PDDT(SPECK_TYPE,0.1,0,1,st1,st0,0,max_p,maxddt,ddt)
        if(ck==1):
            croad.append(ddt[0])
        #opcheck_in_highways(0,p_min,st1,st0)
        #if croad is still empty then fill it with max probility value for other outputs except highway
        if(len(croad) == 0):
            maxddt,ddt,max_p=[0]*1,[],0
            #print(st1,st0,max_p)
            ck,ddt,maxddt=PDDT(SPECK_TYPE,0,0,1,st1,st0,0,max_p,maxddt,ddt)
            #max_p,output,ck=max(0,st1,st0)
            if(ck==1):
                #print(st1,st0,output,max_p)
                #croad.append(NMTS(st1,st0,output,max_p))
                croad.append(maxddt[0])
            else:
                return B_bar,B_cap
        
        #for i in range(0,len(croad)):
            #print(croad[i].dx,croad[i].dy,croad[i].dz,croad[i].wt)
        #check the inputs in highway or not 
        crhw = []
        temphw=[0]*1
        maxddt,ddt,max_p=[0]*1,[],0
        ck,ddt,maxddt=PDDT(SPECK_TYPE,0.1,0,1,st1,st0,0,max_p,maxddt,ddt)
        #val1,val2,val3,w,chk= searchinhighway(st1,st0)
        if(ck==1):
            temphw[0]=NMTS(maxddt[0].dx,maxddt[0].dy,maxddt[0].dz,maxddt[0].wt)
            crhw.extend(temphw)
        
        crhw.extend(croad)
        p_r=1
        for i in range(0,n):
            p_r *= trail_cap[i].wt
        for i in range(0,len(crhw)):
            B_cap_temp[nrounds-1]= p_r * crhw[i].wt * B_cap[nrounds - 1 - (n + 1)]
            if(B_cap_temp[nrounds-1]>B_bar):
                B_barlist[n]=p_r * crhw[i].wt
                trail_cap[n]=NMTS(ROL(crhw[i].dx,alpha),crhw[i].dy,crhw[i].dz,crhw[i].wt)
                st1=crhw[i].dz
                st0=ROL(st0,beta)^st1
                return threshold_search(n+1,nrounds,hw,B_cap,B_bar,B_barlist,st0,st1,op,w1)
            else:
                return B_bar,B_cap
            return B_bar,B_cap
                    
    if(n ==(nrounds - 1)):
        st1=ROR(st1,alpha)
        #print(n)
        maxddt,ddt,max_p=[0]*1,[],0
        ck,ddt,maxddt=PDDT(SPECK_TYPE,0.1,0,1,st1,st0,0,max_p,maxddt,ddt)
        #max_p,output,ck=max(0.1,st1,st0)
        if(ck!=0):
            p=maxddt[0].wt
            op=maxddt[0].dz
        else:
            maxddt,ddt,max_p=[0]*1,[],0
            ck,ddt,maxddt=PDDT(SPECK_TYPE,0,0,1,st1,st0,0,max_p,maxddt,ddt)
            #print(st1,st0,max_p)
            #max_p,output,ck=max(0,st1,st0)
            if(ck==1):
                p=maxddt[0].wt
                op=maxddt[0].dz
            if(p>=0.1):
                hw.append(NMTS(st1,st0,op,p))
        if(ck==0):
            return B_bar,B_cap             
        p_r=1
        for i in range(0,n):
            p_r *= trail_cap[i].wt
        B_cap_temp[nrounds-1]=p * p_r
        if(B_cap_temp[nrounds-1]>B_bar):
            B_barlist[n]=B_cap_temp[nrounds-1]
            #print ("%.16f %.16f" % (B_cap_temp[n],B_bar))
            trail_cap[n]=NMTS(ROL(st1,alpha),st0,op,p)
            B_bar=B_cap_temp[nrounds-1]
            for i in range(0,len(B_cap)):
                B_cap[i]=B_barlist[i]
                B_bar=B_cap_temp[n]  
            for i in range(0,len(trail_cap)):
                print(ROR(trail_cap[i].dx,alpha),trail_cap[i].dy,trail_cap[i].dz,trail_cap[i].wt)
            return B_bar,B_cap
        else:
            return B_bar,B_cap

# %%
import random
import math 
#alpha beta are for left and right circular shift     
alpha, beta = 7,2
#speck total number of round epresented by nrounds
nrounds,n,s=9,0,0
SPECK_TYPE=16
mask,wshift = 2 ** 16 - 1, 15
#B_cap=[0.00048,0.00048,0.0625,0.00048,0.00048,0.00048,0.00048,0.00048,0.00048]
B_cap,B_bar=[2**(-11),2**(-22),2**(-33),2**(-38),2**(-49),2**(-60),2**(-71),2**(-82),2**(-91)],2 ** (-91)
B_barlist=[0]*nrounds
#B_cap,B_bar=[2**(-11),2**(-22),2**(-33),2**(-38)],2 ** (-38)
trail_cap,trail_bar=[0]*nrounds, [0]*nrounds
croad,hw,B_cap_temp=[],[],[0]*nrounds
#st0=(random.randint(1,mask))
#st1=(random.randint(1,mask))
st0=0x4205
st1=0xA60
hlen=408603
max_p,output=0,0
maxddt,ddt,max_p=[0]*1,[],0
print ("%.30f" % B_bar)
class NMTS(object):
    """__init__() functions as the class constructor"""
    def __init__(self, dx=None, dy=None, dz=None, wt=None):
        self.dx = dx
        self.dy = dy
        self.dz = dz
        self.wt = wt
        
highwaylist()
for ch in range(500,len(hw)):
    st0=(random.randint(1,mask))
    st1=(random.randint(1,mask))
    #print(n,nrounds,B_bar,hw[ch].dx,hw[ch].dy,hw[ch].dz,hw[ch].wt)
    B_bar,B_cap =threshold_search(n,nrounds,hw,B_cap,B_bar,B_barlist,st1,st0,0,0)
    #print("%.30f" %B_bar,ch)
    print(B_bar,ch)
    #for i in range(0,len(B_cap)):
        #print(B_cap[i])
# Out:
# 0.000000000000000000000000000404
# 4.0389678347315804e-28 500
# 4.0389678347315804e-28 501
# 4.0389678347315804e-28 502
# 14527 40183 57270 0.00390625
# 28095 44136 49071 0.0009765625
# 24447 3597 61422 0.0009765625
# 56799 55258 62971 0.015625
# 63467 43664 47871 0.000244140625
# 65397 4285 57270 0.00048828125
# 28095 40258 61435 0.00048828125
# 63455 39665 56030 0.0009765625
# 48565 45336 65503 0.00048828125
# 1.6155871338926322e-27 503
# 1.6155871338926322e-27 504
# 1.6155871338926322e-27 505
# 19772 61120 32764 0.0009765625
# 63743 50431 65534 0.0078125
# 65023 60417 61438 0.00048828125
# 64991 24569 24030 0.015625
# 48315 8763 65534 0.0009765625
# 65023 30482 30171 0.00390625
# 46827 43410 65279 0.000244140625
# 65533 22709 24246 0.00390625
# 27837 15459 44990 0.00048828125
# 1.0339757656912846e-25 506
# 1.0339757656912846e-25 507
# 1.0339757656912846e-25 508
# 1.0339757656912846e-25 509
# 1.0339757656912846e-25 510
# 1.0339757656912846e-25 511
# 1.0339757656912846e-25 512
# 1.0339757656912846e-25 513
# 1.0339757656912846e-25 514
# 1.0339757656912846e-25 515
# 1.0339757656912846e-25 516
# 1.0339757656912846e-25 517
# 1.0339757656912846e-25 518
# 1.0339757656912846e-25 519
# 1.0339757656912846e-25 520
# 1.0339757656912846e-25 521
# 1.0339757656912846e-25 522
# 1.0339757656912846e-25 523
# 52059 53151 64506 0.00390625
# 62967 50565 65534 0.0009765625
# 65023 59881 61422 0.0078125
# 56799 18505 28526 0.00048828125
# 56542 20043 28523 0.001953125
# 55006 22086 32628 0.00390625
# 59646 9837 49007 0.0009765625
# 57214 9947 63323 0.001953125
# 47086 27703 47031 0.0009765625
# 2.0679515313825692e-25 524
# 2.0679515313825692e-25 525
# 2.0679515313825692e-25 526
# 2.0679515313825692e-25 527
# 2.0679515313825692e-25 528
# 2.0679515313825692e-25 529
# 2.0679515313825692e-25 530
# 2.0679515313825692e-25 531
# 2.0679515313825692e-25 532
# 2.0679515313825692e-25 533
# 2.0679515313825692e-25 534
# 2.0679515313825692e-25 535
# 2.0679515313825692e-25 536
# 2.0679515313825692e-25 537
# 26359 62332 31607 0.00390625
# 61174 46724 47102 0.001953125
# 64879 28140 28543 0.015625
# 65246 55502 57324 0.0078125
# 55743 48343 57046 0.001953125
# 44477 11656 65519 0.001953125
# 57343 18895 28142 0.0078125
# 56539 19155 28670 0.001953125
# 64735 17587 30682 0.0009765625
# 5.293955920339377e-23 538
# 5.293955920339377e-23 539
# 5.293955920339377e-23 540
# 5.293955920339377e-23 541
# 5.293955920339377e-23 542
# 5.293955920339377e-23 543
# 5.293955920339377e-23 544
# 5.293955920339377e-23 545
# 5.293955920339377e-23 546
# 5.293955920339377e-23 547
# 5.293955920339377e-23 548
# 5.293955920339377e-23 549
# 5.293955920339377e-23 550
# 5.293955920339377e-23 551
# 5.293955920339377e-23 552
# 5.293955920339377e-23 553
# 5.293955920339377e-23 554
# 5.293955920339377e-23 555
# 5.293955920339377e-23 556
# 5.293955920339377e-23 557
# 5.293955920339377e-23 558
# 5.293955920339377e-23 559
# 5.293955920339377e-23 560
# 5.293955920339377e-23 561
# 5.293955920339377e-23 562
# 5.293955920339377e-23 563
# 5.293955920339377e-23 564
# 5.293955920339377e-23 565
# 5.293955920339377e-23 566
# 5.293955920339377e-23 567
# 5.293955920339377e-23 568
# 5.293955920339377e-23 569
# 5.293955920339377e-23 570
# 5.293955920339377e-23 571
# 5.293955920339377e-23 572
# 5.293955920339377e-23 573
# 5.293955920339377e-23 574
# 5.293955920339377e-23 575
# 5.293955920339377e-23 576
# 5.293955920339377e-23 577
# 5.293955920339377e-23 578
# 5.293955920339377e-23 579
# 5.293955920339377e-23 580
# 5.293955920339377e-23 581
# 5.293955920339377e-23 582
# 5.293955920339377e-23 583
# 5.293955920339377e-23 584
# 5.293955920339377e-23 585
# 5.293955920339377e-23 586
# 5.293955920339377e-23 587
# 5.293955920339377e-23 588
# 5.293955920339377e-23 589
# 5.293955920339377e-23 590
# 5.293955920339377e-23 591
# 5.293955920339377e-23 592
# 5.293955920339377e-23 593
# 5.293955920339377e-23 594
# 5.293955920339377e-23 595
# 5.293955920339377e-23 596
# 5.293955920339377e-23 597
# 5.293955920339377e-23 598
# 5.293955920339377e-23 599
# 5.293955920339377e-23 600
# 5.293955920339377e-23 601
# 5.293955920339377e-23 602
# 5.293955920339377e-23 603
# 5.293955920339377e-23 604
# 5.293955920339377e-23 605
# 5.293955920339377e-23 606
# 5.293955920339377e-23 607
# 5.293955920339377e-23 608
# 5.293955920339377e-23 609
# 5.293955920339377e-23 610
# 5.293955920339377e-23 611
# 5.293955920339377e-23 612
# 5.293955920339377e-23 613
# 5.293955920339377e-23 614
# 5.293955920339377e-23 615
# 5.293955920339377e-23 616
# 5.293955920339377e-23 617
# 5.293955920339377e-23 618
# 5.293955920339377e-23 619
# 5.293955920339377e-23 620
# 5.293955920339377e-23 621
# 5.293955920339377e-23 622
# 5.293955920339377e-23 623
# 5.293955920339377e-23 624
# 5.293955920339377e-23 625
# 5.293955920339377e-23 626
# 5.293955920339377e-23 627
# 5.293955920339377e-23 628
# 5.293955920339377e-23 629
# 5.293955920339377e-23 630
# 5.293955920339377e-23 631
# 5.293955920339377e-23 632
# 5.293955920339377e-23 633
# 5.293955920339377e-23 634
# 5.293955920339377e-23 635
# 5.293955920339377e-23 636
# 5.293955920339377e-23 637
# 5.293955920339377e-23 638
# 5.293955920339377e-23 639
# 5.293955920339377e-23 640
# 5.293955920339377e-23 641
# 5.293955920339377e-23 642
# 5.293955920339377e-23 643
# 5.293955920339377e-23 644
# 5.293955920339377e-23 645
# 5.293955920339377e-23 646
# 5.293955920339377e-23 647
# 5.293955920339377e-23 648
# 5.293955920339377e-23 649
# 5.293955920339377e-23 650
# 5.293955920339377e-23 651
# 5.293955920339377e-23 652
# 5.293955920339377e-23 653
# 5.293955920339377e-23 654
# 5.293955920339377e-23 655
# 5.293955920339377e-23 656
# 5.293955920339377e-23 657
# 5.293955920339377e-23 658
# 5.293955920339377e-23 659
# 5.293955920339377e-23 660
# 5.293955920339377e-23 661
# 5.293955920339377e-23 662
# 5.293955920339377e-23 663
# 5.293955920339377e-23 664
# 5.293955920339377e-23 665
# 5.293955920339377e-23 666
# 5.293955920339377e-23 667
# 5.293955920339377e-23 668
# 5.293955920339377e-23 669
# 5.293955920339377e-23 670
# 5.293955920339377e-23 671
# 5.293955920339377e-23 672
# 5.293955920339377e-23 673
# 5.293955920339377e-23 674
# 5.293955920339377e-23 675
# 5.293955920339377e-23 676
# 5.293955920339377e-23 677
# 5.293955920339377e-23 678
# 5.293955920339377e-23 679
# 5.293955920339377e-23 680
# 5.293955920339377e-23 681
# 5.293955920339377e-23 682
# 5.293955920339377e-23 683
# 5.293955920339377e-23 684
# 5.293955920339377e-23 685
# 5.293955920339377e-23 686
# 5.293955920339377e-23 687
# 5.293955920339377e-23 688
# 5.293955920339377e-23 689
# 5.293955920339377e-23 690
# 5.293955920339377e-23 691
# 5.293955920339377e-23 692
# 5.293955920339377e-23 693
# 5.293955920339377e-23 694
# 5.293955920339377e-23 695
# 5.293955920339377e-23 696
# 5.293955920339377e-23 697
# 5.293955920339377e-23 698
# 5.293955920339377e-23 699
# 5.293955920339377e-23 700
# 5.293955920339377e-23 701
# 5.293955920339377e-23 702
# 5.293955920339377e-23 703
# 5.293955920339377e-23 704
# 5.293955920339377e-23 705
# 5.293955920339377e-23 706
# 5.293955920339377e-23 707
# 5.293955920339377e-23 708
# 5.293955920339377e-23 709
# 5.293955920339377e-23 710
# 5.293955920339377e-23 711
# 5.293955920339377e-23 712
# 5.293955920339377e-23 713
# 5.293955920339377e-23 714
# 5.293955920339377e-23 715
# 5.293955920339377e-23 716
# 5.293955920339377e-23 717
# 5.293955920339377e-23 718
# 5.293955920339377e-23 719
# 5.293955920339377e-23 720
# 5.293955920339377e-23 721
# 5.293955920339377e-23 722
# 5.293955920339377e-23 723
# 5.293955920339377e-23 724
# 5.293955920339377e-23 725
# 5.293955920339377e-23 726
# 5.293955920339377e-23 727
# 5.293955920339377e-23 728
# 5.293955920339377e-23 729
# 5.293955920339377e-23 730
# 5.293955920339377e-23 731
# 5.293955920339377e-23 732
# 5.293955920339377e-23 733
# 5.293955920339377e-23 734
# 5.293955920339377e-23 735
# 5.293955920339377e-23 736
# 5.293955920339377e-23 737
# 5.293955920339377e-23 738
# 5.293955920339377e-23 739
# 5.293955920339377e-23 740
# 5.293955920339377e-23 741
# 5.293955920339377e-23 742
# 5.293955920339377e-23 743
# 5.293955920339377e-23 744
# 5.293955920339377e-23 745
# 5.293955920339377e-23 746
# 5.293955920339377e-23 747
